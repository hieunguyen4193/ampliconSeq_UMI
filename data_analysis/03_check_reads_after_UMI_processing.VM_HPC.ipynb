# %%
import pandas as pd 
import os 
import pathlib 
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np
import warnings
from tqdm import tqdm
import subprocess
warnings.filterwarnings("ignore")

##### general settings
output_version = "20250604"
umt_distance = 1

path_to_main_output = f"/workdir/outdir/{output_version}/SampleSheet_UMI_runs/UMT_DISTANCE_{umt_distance}/data_analysis"
os.system(f"mkdir -p {path_to_main_output}")

path_to_02_output = os.path.join(path_to_main_output, "02_output")

path_to_03_output = os.path.join(path_to_main_output, "03_output")
os.system(f"mkdir -p {path_to_03_output}")

umidf = pd.read_csv(os.path.join(path_to_02_output, "all_umis.txt"), sep="\t")
umi_pct_df = pd.read_csv(os.path.join(path_to_02_output, "all_umis_pct.txt"), sep="\t")
entropydf = pd.read_csv(os.path.join(path_to_02_output, "umi_entropy.txt"), sep="\t")

inputdir = f"/workdir/outdir/{output_version}/SampleSheet_UMI_runs/UMT_DISTANCE_{umt_distance}"

samplesheet = pd.read_csv(os.path.join("../experiments/SampleSheet_UMI_runs.csv"))
tmp_excluded_samples = ["45-TMS7E_S7545-S7745", "9-TMPL2S4_S7517-S7717"]
samplesheet = samplesheet[samplesheet["SampleID"].isin(tmp_excluded_samples) == False]
samplesheet["num_valid_umi_reads"] = samplesheet["SampleID"].apply(lambda x: umidf[x].sum())

path_to_unmapped_bam = os.path.join(inputdir, "BISMARK_ALIGNMENT_UNMAPPED_BAM")
path_to_connor_annotated = os.path.join(inputdir, "CONNOR_UMI_OUTPUT")
path_to_connor_fastq = os.path.join(inputdir, "CONNOR_UMI_OUTPUT")
path_to_final_bam = os.path.join(inputdir, "BISMARK_ALIGNMENT")
path_to_cov = os.path.join(inputdir, "BISMARK_COV")

samplesheet["unmapped_bam"] = samplesheet["SampleID"].apply(
    lambda x: [str(item) for item in pathlib.Path(path_to_unmapped_bam).glob(f"{x}*.UMIprocessed_bismark_bt2_pe.bam")][0] 
    if len([str(item) for item in pathlib.Path(path_to_unmapped_bam).glob(f"{x}*.UMIprocessed_bismark_bt2_pe.bam")]) == 1 else "not_available"
)
samplesheet["connor_annotated"] = samplesheet["SampleID"].apply(
    lambda x: [str(item) for item in pathlib.Path(path_to_connor_annotated).glob(f"{x}*.*annotated*.bam")][0] 
    if len([str(item) for item in pathlib.Path(path_to_connor_annotated).glob(f"{x}*.*annotated*.bam")]) == 1 else "not_available"
)
samplesheet["connor_fastq"] = samplesheet["SampleID"].apply(
    lambda x: [str(item) for item in pathlib.Path(path_to_connor_fastq).glob(f"{x}*.*R1*.fastq*")][0] 
    if len([str(item) for item in pathlib.Path(path_to_connor_fastq).glob(f"{x}*.*R1*.fastq*")]) == 1 else "not_available"
)
samplesheet["final_bam"] = samplesheet["SampleID"].apply(
    lambda x: [str(item) for item in pathlib.Path(path_to_final_bam).glob(f"{x}*.*connor*sorted.bam")][0] 
    if len([str(item) for item in pathlib.Path(path_to_final_bam).glob(f"{x}*.*connor*sorted.bam")]) == 1 else "not_available"
)
samplesheet["final_cov"] = samplesheet["SampleID"].apply(
    lambda x: [str(item) for item in pathlib.Path(path_to_cov).glob(f"{x}*.*connor*.cov")][0] 
    if len([str(item) for item in pathlib.Path(path_to_cov).glob(f"{x}*.*connor*.cov")]) == 1 else "not_available"
)


for col in ["unmapped_bam", "connor_annotated", "connor_fastq", "final_bam" , "final_cov"]:
    def _get_line_count(x):
        if x == "not_available":
            return 0
        try:
            if ".bam" in x:
                result = subprocess.run(f"samtools view {x} -c", shell=True, capture_output=True, text=True)
            elif ".fastq.gz" in x:
                result = subprocess.run(f"zcat {x} | wc -l", shell=True, capture_output=True, text=True)
            else:
                result = subprocess.run(f"cat {x} | wc -l", shell=True, capture_output=True, text=True)
            return int(result.stdout.strip())
        except Exception:
            return 0
    samplesheet[f"count_{col}"] = samplesheet[col].apply(_get_line_count)

# %%
samplesheet[(samplesheet["unmapped_bam"] != "not_available") & 
            (samplesheet["final_cov"] != "not_available")]
# Out:
#                   SampleID                                             FASTQ1  \
# 0    10-TML2S5_S7510-S7710  /mnt/GS-BACKUP05/FASTQ/2025/R7288/zatm/10-TML2...
# 1    11-TML3S1_S7511-S7711  /mnt/GS-BACKUP05/FASTQ/2025/R7288/zatm/11-TML3...
# 2    12-TML3S2_S7512-S7712  /mnt/GS-BACKUP05/FASTQ/2025/R7288/zatm/12-TML3...
# 3    13-TML3S3_S7513-S7713  /mnt/GS-BACKUP05/FASTQ/2025/R7288/zatm/13-TML3...
# 4    14-TML3S4_S7514-S7714  /mnt/GS-BACKUP05/FASTQ/2025/R7288/zatm/14-TML3...
# ..                     ...                                                ...
# 103  3-TMPL1S3_S7511-S7711  /mnt/GS-BACKUP05/FASTQ/2025/R7312/zatm/3-TMPL1...
# 104  4-TMPL1S4_S7512-S7712  /mnt/GS-BACKUP05/FASTQ/2025/R7312/zatm/4-TMPL1...
# 105  5-TMPL1S5_S7513-S7713  /mnt/GS-BACKUP05/FASTQ/2025/R7312/zatm/5-TMPL1...
# 107  7-TMPL2S2_S7515-S7715  /mnt/GS-BACKUP05/FASTQ/2025/R7312/zatm/7-TMPL2...
# 108  8-TMPL2S3_S7516-S7716  /mnt/GS-BACKUP05/FASTQ/2025/R7312/zatm/8-TMPL2...
#
#                                                 FASTQ2  num_valid_umi_reads  \
# 0    /mnt/GS-BACKUP05/FASTQ/2025/R7288/zatm/10-TML2...              1499452
# 1    /mnt/GS-BACKUP05/FASTQ/2025/R7288/zatm/11-TML3...               815024
# 2    /mnt/GS-BACKUP05/FASTQ/2025/R7288/zatm/12-TML3...               796800
# 3    /mnt/GS-BACKUP05/FASTQ/2025/R7288/zatm/13-TML3...               874550
# 4    /mnt/GS-BACKUP05/FASTQ/2025/R7288/zatm/14-TML3...              1289061
# ..                                                 ...                  ...
# 103  /mnt/GS-BACKUP05/FASTQ/2025/R7312/zatm/3-TMPL1...              1617109
# 104  /mnt/GS-BACKUP05/FASTQ/2025/R7312/zatm/4-TMPL1...              1721808
# 105  /mnt/GS-BACKUP05/FASTQ/2025/R7312/zatm/5-TMPL1...              1472132
# 107  /mnt/GS-BACKUP05/FASTQ/2025/R7312/zatm/7-TMPL2...               201263
# 108  /mnt/GS-BACKUP05/FASTQ/2025/R7312/zatm/8-TMPL2...               201040
#
#                                           unmapped_bam  \
# 0    /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 1    /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 2    /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 3    /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 4    /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# ..                                                 ...
# 103  /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 104  /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 105  /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 107  /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 108  /workdir/outdir/20250604/SampleSheet_UMI_runs/...
#
#                                       connor_annotated  \
# 0    /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 1    /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 2    /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 3    /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 4    /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# ..                                                 ...
# 103  /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 104  /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 105  /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 107  /workdir/outdir/20250604/SampleSheet_UMI_runs/...
# 108  /workdir/outdir/20250604/SampleSheet_UMI_runs/...
#
#                                           connor_fastq      final_bam  \
# 0    /workdir/outdir/20250604/SampleSheet_UMI_runs/...  not_available
# 1    /workdir/outdir/20250604/SampleSheet_UMI_runs/...  not_available
# 2    /workdir/outdir/20250604/SampleSheet_UMI_runs/...  not_available
# 3    /workdir/outdir/20250604/SampleSheet_UMI_runs/...  not_available
# 4    /workdir/outdir/20250604/SampleSheet_UMI_runs/...  not_available
# ..                                                 ...            ...
# 103  /workdir/outdir/20250604/SampleSheet_UMI_runs/...  not_available
# 104  /workdir/outdir/20250604/SampleSheet_UMI_runs/...  not_available
# 105  /workdir/outdir/20250604/SampleSheet_UMI_runs/...  not_available
# 107  /workdir/outdir/20250604/SampleSheet_UMI_runs/...  not_available
# 108  /workdir/outdir/20250604/SampleSheet_UMI_runs/...  not_available
#
#                                              final_cov  count_unmapped_bam  \
# 0    /workdir/outdir/20250604/SampleSheet_UMI_runs/...             2859666
# 1    /workdir/outdir/20250604/SampleSheet_UMI_runs/...              419212
# 2    /workdir/outdir/20250604/SampleSheet_UMI_runs/...              346982
# 3    /workdir/outdir/20250604/SampleSheet_UMI_runs/...              306902
# 4    /workdir/outdir/20250604/SampleSheet_UMI_runs/...             1623828
# ..                                                 ...                 ...
# 103  /workdir/outdir/20250604/SampleSheet_UMI_runs/...             3011172
# 104  /workdir/outdir/20250604/SampleSheet_UMI_runs/...             3203444
# 105  /workdir/outdir/20250604/SampleSheet_UMI_runs/...             2768900
# 107  /workdir/outdir/20250604/SampleSheet_UMI_runs/...                4766
# 108  /workdir/outdir/20250604/SampleSheet_UMI_runs/...               38612
#
#      count_connor_annotated  count_connor_fastq  count_final_bam  \
# 0                   2856735               13468                0
# 1                    415074                7612                0
# 2                    290902                6712                0
# 3                    304192                7464                0
# 4                   1468385                9808                0
# ..                      ...                 ...              ...
# 103                 2870661               16476                0
# 104                 3099356               20672                0
# 105                 2655720               13024                0
# 107                    4757                1108                0
# 108                   37747                4932                0
#
#      count_final_cov
# 0                 15
# 1                 13
# 2                 13
# 3                 14
# 4                 13
# ..               ...
# 103               26
# 104               43
# 105               43
# 107               26
# 108               26
#
# [102 rows x 14 columns]

# %%
[str(item) for item in pathlib.Path(path_to_final_bam).glob(f"*.*connor*.bam")]
# Out:
# ['/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/34-TML10S4_S7534-S7734.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/42-TMPANEL2_S7542-S7742.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/32-TML10S2_S7532-S7732.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/43-TMPANEL3_S7543-S7743.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/35-TML10S5_S7535-S7735.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/21-TML6S1_S7566-S7766.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/1-TML4S1_S7546-S7746.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/31-TML10S1_S7531-S7731.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/33-TML10S3_S7533-S7733.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/13-TML3S3_S7513-S7713.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/11-TML3S1_S7511-S7711.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/7-TML2S2_S7507-S7707.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/12-TML3S2_S7512-S7712.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/27-TML14S2_S7572-S7772.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/22-TML6S2_S7567-S7767.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/22-TML8S2_S7522-S7722.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/29-TML14S4_S7574-S7774.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT
connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/2-TMPL1S2_S7510-S7710.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/1-TMPL1S1_S7509-S7709.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/9-TML7S4_S7554-S7754.connor_R1_bismark_bt2_pe.bam',
#  '/workdir/outdir/20250604/SampleSheet_UMI_runs/UMT_DISTANCE_1/BISMARK_ALIGNMENT/4-TMPL1S4_S7512-S7712.connor_R1_bismark_bt2_pe.bam']

# %%
samplesheet[[item for item in samplesheet.columns if "count_" in item]]
# Out:
#      count_unmapped_bam  count_connor_annotated  count_connor_fastq  \
# 0               2859666                 2856735               13468
# 1                419212                  415074                7612
# 2                346982                  290902                6712
# 3                306902                  304192                7464
# 4               1623828                 1468385                9808
# ..                  ...                     ...                 ...
# 104             3203444                 3099356               20672
# 105             2768900                 2655720               13024
# 106                 320                     319                  36
# 107                4766                    4757                1108
# 108               38612                   37747                4932
#
#      count_final_bam  count_final_cov
# 0                  0               15
# 1                  0               13
# 2                  0               13
# 3                  0               14
# 4                  0               13
# ..               ...              ...
# 104                0               43
# 105                0               43
# 106                0                0
# 107                0               26
# 108                0               26
#
# [108 rows x 5 columns]

# %%
samplesheet.count_final_bam.unique()
# Out:
# array([0])

# %%
plotdf = samplesheet[["SampleID", "num_valid_umi_reads"] + [item for item in samplesheet.columns if "count_" in item and "cov" not in item]].set_index("SampleID").T

plt.figure(figsize=(40, 10))
plotdf.plot.line()
plt.xticks(rotation=90)
plt.legend([])
plt.show()

# %%
plotdf = samplesheet[["SampleID"] + ["count_final_bam", "count_final_cov"]].set_index("SampleID").T

plt.figure(figsize=(40, 10))
plotdf.plot.line()
plt.xticks([], rotation=90)
plt.legend([])
plt.show()

# %%
plotdf
# Out:
# SampleID         10-TML2S5_S7510-S7710  11-TML3S1_S7511-S7711  \
# count_final_bam                      0                      0
# count_final_cov                     15                     13
#
# SampleID         12-TML3S2_S7512-S7712  13-TML3S3_S7513-S7713  \
# count_final_bam                      0                      0
# count_final_cov                     13                     14
#
# SampleID         14-TML3S4_S7514-S7714  15-TML3S5_S7515-S7715  \
# count_final_bam                      0                      0
# count_final_cov                     13                     13
#
# SampleID         16-TML5S1_S7516-S7716  17-TML5S2_S7517-S7717  \
# count_final_bam                      0                      0
# count_final_cov                      9                      9
#
# SampleID         18-TML5S3_S7518-S7718  19-TML5S4_S7519-S7719  ...  \
# count_final_bam                      0                      0  ...
# count_final_cov                      9                      9  ...
#
# SampleID         19-TMPL4S4_S7527-S7727  1-TMPL1S1_S7509-S7709  \
# count_final_bam                       0                      0
# count_final_cov                      39                     42
#
# SampleID         20-TMPL4S5_S7528-S7728  2-TMPL1S2_S7510-S7710  \
# count_final_bam                       0                      0
# count_final_cov                      24                     43
#
# SampleID         3-TMPL1S3_S7511-S7711  4-TMPL1S4_S7512-S7712  \
# count_final_bam                      0                      0
# count_final_cov                     26                     43
#
# SampleID         5-TMPL1S5_S7513-S7713  6-TMPL2S1_S7514-S7714  \
# count_final_bam                      0                      0
# count_final_cov                     43                      0
#
# SampleID         7-TMPL2S2_S7515-S7715  8-TMPL2S3_S7516-S7716
# count_final_bam                      0                      0
# count_final_cov                     26                     26
#
# [2 rows x 108 columns]

# %%
samplesheet[["num_valid_umi_reads", "count_unmapped_bam"]].boxplot()
# Out:
# <Axes: >
